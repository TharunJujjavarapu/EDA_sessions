# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path="C:\\Users\\lenovo\\Desktop\\Data Science course\\Data Files\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.columns[-1]#target column
# Out:
# 'case_status'

# %%
visa_df.columns[:len(visa_df.columns)-1]#input columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position'],
#       dtype='object')

# %%
visa_df['continent'].value_counts()
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# Certified    17018
# Denied        8462
# Name: case_status, dtype: int64

# %%
#Q1) out of all Asia applicants how many are certified and how many are denied
# in Asia 16861 people applied for Visa
# in that how many are getting and how many are not getting

# %%
cond1=visa_df['continent']=='Asia'
cond2=visa_df['case_status']=='Certified'
print("The number of certified applicants from Asia is:",len(visa_df[cond1&cond2]))

cond1=visa_df['continent']=='Europe'
cond2=visa_df['case_status']=='Certified'
print("The number of certified applicants from Europe is:",len(visa_df[cond1&cond2]))

cond1=visa_df['continent']=='North America'
cond2=visa_df['case_status']=='Certified'
print("The number of certified applicants from North America is:",len(visa_df[cond1&cond2]))

cond1=visa_df['continent']=='South America'
cond2=visa_df['case_status']=='Certified'
print("The number of certified applicants from South America is:",len(visa_df[cond1&cond2]))

cond1=visa_df['continent']=='Africa'
cond2=visa_df['case_status']=='Certified'
print("The number of certified applicants from Africa is:",len(visa_df[cond1&cond2]))

cond1=visa_df['continent']=='Oceania'
cond2=visa_df['case_status']=='Certified'
print("The number of certified applicants from oceania is:",len(visa_df[cond1&cond2]))
# Out:
# The number of certified applicants from Asia is: 11012
# The number of certified applicants from Europe is: 2957
# The number of certified applicants from North America is: 2037
# The number of certified applicants from South America is: 493
# The number of certified applicants from Africa is: 397
# The number of certified applicants from oceania is: 122

# %%
visa_df['continent'].value_counts()
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %%
keys=visa_df['continent'].value_counts().keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object')

# %%
keys=visa_df['continent'].value_counts().keys()
for i in keys:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    count=len(visa_df[con1&con2])
    print("The number of certified applicants from {} is: {}".format(i,count))
    
for i in keys:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Denied'
    count=len(visa_df[con1&con2])
    print("The number of Denied applicants from {} is: {}".format(i,count))
# Out:
# The number of certified applicants from Asia is: 11012
# The number of certified applicants from Europe is: 2957
# The number of certified applicants from North America is: 2037
# The number of certified applicants from South America is: 493
# The number of certified applicants from Africa is: 397
# The number of certified applicants from Oceania is: 122
# The number of Denied applicants from Asia is: 5849
# The number of Denied applicants from Europe is: 775
# The number of Denied applicants from North America is: 1255
# The number of Denied applicants from South America is: 359
# The number of Denied applicants from Africa is: 154
# The number of Denied applicants from Oceania is: 70

# %%
certified=[]
denied=[]
keys=visa_df['continent'].value_counts().keys()
for i in keys:
    cond1=visa_df['continent']==i
    cond2=visa_df['case_status']=='Certified'
    cond3=visa_df['case_status']=='Denied'
    count1=len(visa_df[cond1&cond2])
    count2=len(visa_df[cond1&cond3])
    certified.append(count1)
    denied.append(count2)
    
pd.DataFrame(zip(certified,denied),columns=['Certified','Denied'],index=keys)
# Out:
#                Certified  Denied
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# South America        493     359
# Africa               397     154
# Oceania              122      70

# %% [markdown]
# **pd.crosstab**

# %%
# Continent / Case_status
col1=visa_df['continent']
col2=visa_df['case_status']
result1=pd.crosstab(col1,col2)
result1
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
result1.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#multivariate
#'continent', 'education_of_employee','case_status'
col1=visa_df['continent']
col2=visa_df['education_of_employee']
col3=visa_df['case_status']
#you need to combine any two columns
col=[col2,col3]
result2=pd.crosstab(col,col1)
result2
# Out:
# continent                          Africa  Asia  Europe  North America  \
# education_of_employee case_status
# Bachelor's            Certified        81  4407    1040            641
#                       Denied           62  2761     259            584
# Doctorate             Certified        43   780     788            207
#                       Denied           11   143      58             51
# High School           Certified        23   676     162            210
#                       Denied           43  1614     328            191
# Master's              Certified       250  5149     967            979
#                       Denied           38  1331     130            429
#
# continent                          Oceania  South America
# education_of_employee case_status
# Bachelor's            Certified         38            160
#                       Denied            28            173
# Doctorate             Certified         19             75
# ...

# %%
result2.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='education_of_employee,case_status'>

# %% [markdown]
# **Numerical columns**

# %%
#get only numerical columns
num_cols=[i for i in dict(visa_df.dtypes) if dict(visa_df.dtypes)[i]!='O' ]
num_cols
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
#Get Numerical col
visa_df.select_dtypes(include=(int,float)).columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **scatter plot**

# %%
x=[1,2,3,4,5]
y=[10,11,12,13,14]
plt.scatter(x,y)

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)

# %%
col1=visa_df['no_of_employees']
col2=visa_df['prevailing_wage']
plt.scatter(col1,col2)
plt.xlabel('no_of_employees')
plt.ylabel('prevailing_wage')
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %% [markdown]
# $Correlation$-$coefficinet$:
#
# - It is denoted with r
#
# - r varies from -1 to 1
#
# - for negative correlation r = [-1,0)
#
# - for postive correlation r=(0,1]
#
# - for no relation r=0

# %% [markdown]
# <img class="XqHOTb IGEbUc" alt="r =\frac{\sum\left(x_{i}-\bar{x}\right)\left(y_{i}-\bar{y}\right)}{\sqrt{\sum\left(x_{i}-\bar{x}\right)^{2} \sum\left(y_{i}-\bar{y}\right)^{2}}}" src="https://www.gstatic.com/education/formulas2/553212783/en/correlation_coefficient_formula.svg" role="img" data-csiid="27" data-atf="1">

# %% [markdown]
# **corr()**

# %%
#Covariance$-$matrix:
    
#3 numerical coluns

#3x3 matrix

#       'no_of_employees'  'yr_of_establishment'  'p_wagw'
    
#'no_emp'  var(1)             covar                 covar ~=0

#'yr_est'   covar              var(1)                 covar
 
#'p_wage'   covar              covar                  var(1)


#'no_emp' with 'p_Wage' the scatter plot says no relation
#covar('no_emp' ,'p_wage') ~0

# %%
num_cols
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
# Read the datafarme again

visa_df.corr()

# r value between= no_of_employees  and prevailing_wage = -0.0095
# No relation
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\lenovo'

# %%
plt.scatter(visa_df['yr_of_estab'],visa_df['prevailing_wage'])

# %% [markdown]
# **corr()**

# %%
#corr function
# matrix 
# showing values in a matrix 
# showing values in a picture: Heatmap

# %%
corr_data=visa_df.corr()
corr_data
sns.heatmap(corr_data,annot=True)
# Out:
# <AxesSubplot:>
